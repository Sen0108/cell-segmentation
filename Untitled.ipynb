# %%
import numpy as np
import cv2 as cv
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv.imread("/Users/dtarasia/Desktop/cell-segmentation/6115.png")
plt.imshow(img)

# %%
img_hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
img_hsv[121,201]
# Out:
# array([ 15, 208, 119], dtype=uint8)
