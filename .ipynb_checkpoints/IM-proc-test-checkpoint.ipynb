# %%
import numpy as np
import cv2 as cv
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
path = "/home/devesh/cell-segmentation/images/"
files = os.listdir(path)
files.remove('.ipynb_checkpoints')
files.remove('.DS_Store')
files.sort()

# %%
img_lst = []
for i in files:
    name = os.path.join(path,i)
    img_bgr = cv.imread(name)
    img_rgb = cv.cvtColor(img_bgr,cv.COLOR_BGR2RGB)
    img_lst.append(img_rgb)

# %%
plt.imshow(img_lst[7])
plt.axis('off')
# Out:
# (-0.5, 1839.5, 1839.5, -0.5)

# %%
#RGB based filtering
#cell_masks = []
#dna_masks = []
#imgs_filtered = []
#for (i,img_rgb) in enumerate(img_lst):
#    r,g,b = cv.split(img_rgb)
#    _,cell_mask = cv.threshold(b,40,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
#    _,dna_mask = cv.threshold(g,65,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
#    cell_masks.append(cell_mask)
#    dna_masks.append(dna_mask)
#    res = cv.bitwise_and(img_rgb,img_rgb,mask=cell_mask)
#    res_bgr = cv.cvtColor(res,cv.COLOR_RGB2BGR)
#    new_name = "/Users/dtarasia/Desktop/cell-segmentation/filtered-images/"+files[i]
#    cv.imwrite(new_name,res_bgr)
#    imgs_filtered.append(res)

# %%
green_low_h = int(128/2)
green_high_h = int(144/2)
green_low_s = int(0/100*255)
green_high_s = int(100/100*255)
green_low_v = int(25/100*255)
green_high_v = int(100/100*255)

low_green = np.array([green_low_h,green_low_s,green_low_v])
high_green = np.array([green_high_h,green_high_s,green_high_v])

blue_low_h = int(210/2)
blue_high_h = int(240/2)
blue_low_s = int(0/100*255)
blue_high_s = int(100/100*255)
blue_low_v = int(25/100*255)
blue_high_v = int(100/100*255)

low_blue = np.array([blue_low_h,blue_low_s,blue_low_v])
high_blue = np.array([blue_high_h,blue_high_s,blue_high_v])

cell_masks = []
dna_masks = []
cells_hsv = []
full_masks = []
kernel_size = 550
for (i,img_rgb) in enumerate(img_lst):
    img_bgr = cv.cvtColor(img_rgb,cv.COLOR_RGB2BGR)
    img_hsv = cv.cvtColor(img_bgr,cv.COLOR_BGR2HSV)
    
    cell_mask = cv.inRange(img_hsv,low_blue,high_blue)
    dna_mask = cv.inRange(img_hsv,low_green,high_green)
    
    #cell_mask = cv.medianBlur(cell_mask,kernel_size)
    #dna_mask = cv.medianBlur(dna_mask,kernel_size)
    
    cell_masks.append(cell_mask)
    dna_masks.append(dna_mask)
    full_masks.append(cv.bitwise_or(cell_mask,dna_mask))
    
    
    cv.imwrite("/Users/dtarasia/Desktop/cell-segmentation/dna_masks/"+files[i],dna_mask)
    cv.imwrite("/Users/dtarasia/Desktop/cell-segmentation/cell_masks/"+files[i],cell_mask)
    
    #cells_hsv.append(img_hsv)

# %%
files.index('06.tif')
# Out:
# 5

# %%
n = 5
files[n]
# Out:
# '06.tif'

# %%
plt.imshow(full_masks[n],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1839.5, 1839.5, -0.5)

# %%
for (i,full_mask) in enumerate(full_masks):
    contours, hierarchy = cv.findContours(image=full_mask,mode=cv.RETR_TREE,method=cv.CHAIN_APPROX_NONE)
    cv.drawContours(image=full_mask, contours=contours, contourIdx=-1, color=(255,0,0), thickness=2, lineType=cv.LINE_AA)
    full_masks[i] = full_mask

# %%
#Flood fill, not working
#for (i,full_mask) in enumerate(full_masks):
#    h, w = full_mask.shape[:2]
#    mask = np.zeros((h+2, w+2), np.uint8)
#    cv.floodFill(full_mask, mask, (2,2), 255)
#    full_floodfill_inv = cv.bitwise_not(full_mask)
#    im_out = full_mask | full_floodfill_inv
#    full_masks[i] = im_out

# %%
n = 5
plt.imshow(full_masks[n],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1839.5, 1839.5, -0.5)

# %%
#Dilation
kernel = np.ones((5,5), np.uint8)
dilated_imgs = []
for (i,full_mask) in enumerate(full_masks):
    dilated_imgs.append(cv.dilate(full_mask,kernel,iterations=15))

# %%
plt.imshow(dilated_imgs[n],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1839.5, 1839.5, -0.5)

# %%
#Dilation Function
def dilation(img_list,kernel_mat,num_iter):
    dilated_imgs = []
    for (i,img) in enumerate(img_list):
        dilated_imgs.append(cv.dilate(img,kernel=kernel_mat,iterations=num_iter))
    
    return dilated_imgs

# %%
closings = []
for (i,img) in enumerate(full_masks):
    closing = cv.morphologyEx(img,cv.MORPH_OPEN,kernel,iterations=2)
    closings.append(closing)

# %%
sure_fgs = []
for (i,img) in enumerate(closings):
    dist_transform = cv.distanceTransform(img,cv.DIST_L2,0)
    ret2, sure_fg = cv.threshold(dist_transform,0.5*dist_transform.max(),255,0)
    sure_fgs.append(sure_fg)

# %%
plt.imshow(sure_fgs[n],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1839.5, 1839.5, -0.5)

# %%
connected_comps = []
for (i,img) in enumerate(sure_fgs):
    ret3, markers = cv.connectedComponents(img)
    connected_comps.append(markers)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [94], in <module>
#       1 connected_comps = []
#       2 for (i,img) in enumerate(sure_fgs):
# ----> 3     ret3, markers = cv.connectedComponents(img)
#       4     connected_comps.append(markers)
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/connectedcomponents.cpp:5632: error: (-215:Assertion failed) iDepth == CV_8U || iDepth == CV_8S in function 'connectedComponents_sub1'
